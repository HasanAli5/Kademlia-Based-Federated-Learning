# %%
import data
import numpy

dataset = numpy.load("./data/chestmnist.npz")
print(dataset)
# Out:
# NpzFile './data/chestmnist.npz' with keys: train_images, val_images, test_images, train_labels, val_labels...

# %%
from PIL import Image
from  matplotlib import pyplot
#print(dataset["train_images"])

img = Image.fromarray(dataset["train_images"][1])
imageplot = pyplot.imshow(img,cmap="gray")
#img.show()
pyplot.show()

# %%
print(list(dataset.keys()))
# Out:
# ['train_images', 'val_images', 'test_images', 'train_labels', 'val_labels', 'test_labels']
